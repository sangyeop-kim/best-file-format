# %%
import pandas as pd

# %%
df = pd.read_feather('./phm_data_challenge_2018_sample/sample_data.ftr')

# %%
df
# Out:
#              time   Tool  stage   Lot    runnum  recipe  recipe_step  \
# 0         3283718  02M01      1   630  10511677       1            1
# 1         3283722  02M01      1   630  10511677       1            1
# 2         3283726  02M01      1   630  10511677       1            1
# 3         3283730  02M01      1   630  10511677       1            1
# 4         3283734  02M01      1   630  10511677       1            1
# ...           ...    ...    ...   ...       ...     ...          ...
# 2865620  32494954  02M01    159  8455  12387355       5            3
# 2865621  32494958  02M01    159  8455  12387355       5            3
# 2865622  32494962  02M01    159  8455  12387355       5            3
# 2865623  32494966  02M01    159  8455  12387355       5            3
# 2865624  32494970  02M01    159  8455  12387355       5            3
#
#          IONGAUGEPRESSURE  ETCHBEAMVOLTAGE  ETCHBEAMCURRENT  ...  \
# 0               -1.392654        -1.466228        -1.438830  ...
# ...

# %%
df.to_feather('sample_data.ftr')

# %%
def write_file(extension, model_dict, filename, format_ = None, compression = None, 
               orient = 'table', complib = 'zlib', parquet_comp = 'snappy') :
    
    '''
    pd.to_csv, compression : {‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}, default ‘infer’
    pd.to_json, orient : {‘split’, ‘records’, ‘index’, ‘columns’, ‘values’, ‘table’}, 
                        default 'columns' 
                compression{‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}, default 'infer'
    pd.to_excel, None 
    pd.to_hdf, complib : {‘zlib’, ‘lzo’, ‘bzip2’, ‘blosc’}, default ‘zlib’, 
                    format : {‘fixed’, ‘table’, None}, default ‘fixed’,
    pd.to_feather, None
    pd.to_parquet, compression{‘snappy’, ‘gzip’, ‘brotli’, None}, default ‘snappy’
    pd.to_stata, None
    pd.to_pickle, compression{‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}, default ‘infer’
    '''

    if extension == 'h5':
        model_dict[day].to_hdf('test_%s.%s' % (filename,extension), format_, complib = complib)
    elif extension == 'xlsx':
        model_dict[day].to_excel('test_%s.%s' % (filename,extension))
    elif extension == 'csv':
        model_dict[day].to_csv('test_%s.%s' % (filename,extension), compression = compression)
    elif extension == 'json':
        model_dict[day].to_json('test_%s.%s' % (filename,extension), orient = orient, 
                                compression = compression)
    elif extension == 'ftr':
        model_dict[day].to_feather('test_%s.%s' % (filename,extension))
    elif extension == 'parquet':
        model_dict[day].to_parquet('test_%s.%s' % (filename,extension), compression = parquet_comp)
    elif extension == 'dta':
        model_dict[day].to_stata('test_%s.%s' % (filename,extension))
    elif extension == 'pkl':
        model_dict[day].to_pickle('test_%s.%s' % (filename,extension), compression = compression)

# %%
format_ = ['fixed', 'table']
compression = ['gzip', 'bz2', 'zip', 'xz']
orient = ['split', 'records', 'index', 'columns', 'values', 'table']
complib = ['zlib', 'lzo', 'bzip2', 'blosc']
parquet_comp = ['snappy', 'gzip', 'brotli']
